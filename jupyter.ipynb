# %%
# %%javascript
#
# const imagens = {
#     0: 'numero0.png',
#     1: 'numero1.png',
#     2: 'numero2.png',
#     3: 'numero3.png',
#     4: 'numero4.png',
#     5: 'numero5.png',
#     6: 'numero6.png',
#     7: 'numero7.png',
#     8: 'numero8.png',
#     9: 'numero9.png'
# };
#
# const idade = '17';
#
# for (const ida of idade) {
#     if (ida === '1') {
#         element.text(1);
#     }
# }

# %%
# %%javascript
#
# const cores = {
#     0: 'red',
#     1: 'blue',
#     2: 'black',
#     3: 'white',
#     4: 'green',
#     5: 'pink',
#     6: 'yelloy',
#     7: 'light',
# }
#
# let inde = Math.floor(Math.random() * Object.keys(objeto).length); // pega a quantidade de elementos do objeto
#
# element.text(objeto[inde]);
